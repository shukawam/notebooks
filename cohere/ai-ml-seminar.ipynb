# %% [markdown]
# ### Prepare

# %%
import cohere
import textwrap as tr

API_KEY = 'RTelVPbMQAj3nKZcNVTiqKBBkNTf6vqqyPPB3fOv'

co = cohere.Client(API_KEY)
co.check_api_key()
# Out:
# {'valid': True}

# %% [markdown]
# ### Generate

# %%
def generate_text(prompt):
    return co.generate(
        model = "command-light-nightly",
        prompt = prompt,
        max_tokens = 75,
        temperature = 0.4
    )

print(generate_text("Hello World is a program that"))
# Out:
# [cohere.Generation {
# 	id: ff00b19e-da35-4e40-9287-8240e5f215be
# 	prompt: Hello World is a program that
# 	text:  Hello World is a program that prints "Hello World" to the console. It is a classic example of a simple program that demonstrates the basic concepts of programming. The phrase "Hello World" has been used as a standard test of a programming language's compatibility since the early days of computer programming. It is often used as a benchmark to evaluate the performance of a programming language or
# 	likelihood: None
# 	finish_reason: MAX_TOKENS
# 	token_likelihoods: None
# }]

# %% [markdown]
# ### Chat

# %%
def chat_plane(message, chat_history):
    if chat_history != None:
        response = co.chat(
            message = message,
            model = 'command-light-nightly',
            chat_history = chat_history,
        )
    else:
        response = co.chat(
            message = message,
            model = 'command-light-nightly',
        )
    return response

message = "What is OKE?"
chat_plane(message, None)
# Out:
# cohere.Chat {
# 	id: 05b43272-06b1-4b3b-a0a8-3e8e8e8dfb91
# 	response_id: 05b43272-06b1-4b3b-a0a8-3e8e8e8dfb91
# 	generation_id: 4c7c8e63-9e4b-4469-bba2-786329c598d6
# 	message: What is OKE?
# 	text: OKE stands for "Open Knowledge Exchange". It is a platform that allows users to share and collaborate on open-source knowledge projects. The platform is designed to be intuitive and easy to use, and it aims to encourage knowledge sharing and collaboration on a global scale.
#
# Would you like to know more about OKE?
# 	conversation_id: None
# 	prompt: None
# 	chatlog: None
# 	preamble: None
# 	client: <cohere.client.Client object at 0x7f513500b880>
# 	token_count: {'prompt_tokens': 67, 'response_tokens': 65, 'total_tokens': 132, 'billed_tokens': 121}
# 	meta: {'api_version': {'version': '1'}}
# 	is_search_required: None
# 	citations: None
# 	documents: None
# 	search_results: None
# 	search_queries: None
# }

# %%
connectors = [
    {
        "id": "web-search",
        "options": {
            "site": "https://www.oracle.com/cloud/cloud-native/container-engine-kubernetes/"
        }
    }
]

def chat_with_rag(message, chat_history):
    if chat_history != None:
        response = co.chat(
            message = message,
            model = 'command-light-nightly',
            chat_history = chat_history,
            connectors=connectors
        )
    else:
        response = co.chat(
            message = message,
            model = 'command-light-nightly',
            connectors=connectors
        )
    return response

message = "What is OKE?"
print(chat_with_rag(message, None))
# Out:
# cohere.Chat {
# 	id: 1a380202-396c-4a67-a502-45d3c18a0561
# 	response_id: 1a380202-396c-4a67-a502-45d3c18a0561
# 	generation_id: ff70e3c9-ae60-4125-a34b-6733f718e8c1
# 	message: What is OKE?
# 	text: Oracle Cloud Infrastructure Container Engine for Kubernetes (OKE) is a managed Kubernetes service that simplifies the operations of enterprise-grade Kubernetes at scale. It reduces the time, cost, and effort needed to manage the complexities of the Kubernetes infrastructure.
# 	conversation_id: None
# 	prompt: None
# 	chatlog: None
# 	preamble: None
# 	client: <cohere.client.Client object at 0x7f513500b880>
# 	token_count: {'prompt_tokens': 1355, 'response_tokens': 47, 'total_tokens': 1402, 'billed_tokens': 52}
# 	meta: {'api_version': {'version': '1'}}
# 	is_search_required: None
# 	citations: [{'start': 0, 'end': 65, 'text': 'Oracle Cloud Infrastructure Container Engine for Kubernetes (OKE)', 'document_ids': ['web-search_0:0']}, {'start': 71, 'end': 97, 'text': 'managed Kubernetes service', 'document_ids': ['web-search_0:0']}, {'start': 103, 'end': 169, 'text': 'simplifies the operations of enterprise-grade Kubernetes at scale.', 'document_ids': ['web-search_0:0']}, {'start': 173, 'end': 214, 'text': 'reduces the time, cost, and effort needed', 'document_ids': ['web-search_0:0']}, {'start': 218, 'end': 275, 'text': 'manage the complexities of the Kubernetes infrastructure.', 'document_ids': ['web-search_0:0']}]
# 	documents: [{'id': 'web-search_0:0', 'snippet': 'Accessibility Policy\n\nSearch Menu Contact Sales Sign in to Oracle Cloud\n\nContainer Engine for Kubernetes\n\nOracle Cloud Infrastructure Container Engine for Kubernetes (OKE) is a managed Kubernetes service that simplifies the operations of enterprise-grade Kubernetes at scale. It reduces the time, cost, and effort needed to manage the complexities of the Kubernetes infrastructure. Container Engine for Kubernetes lets you deploy Kubernetes clusters and ensure reliable operations for both the control plane and the worker nodes with automatic scaling, upgrades, and security patching. Additionally, OKE provides a fully serverless Kubernetes experience with virtual nodes.\n\nOracle Container Engine for Kubernetes (OKE) (2:31)\n\nServerless Kubernetes with virtual nodes\n\nVirtual nodes provide a serverless Kubernetes experience to run containerized applications at scale without spending additional resources on managing, scaling, upgrading, and troubleshooting the infrastructure of your clusters.', 'title': 'Container Engine for Kubernetes | Oracle', 'url': 'https://www.oracle.com/cloud/cloud-native/container-engine-kubernetes/'}]
# 	search_results: [{'search_query': {'text': 'What is OKE?', 'generation_id': '1604de91-200c-4931-9d71-e91d607942a7'}, 'document_ids': ['web-search_0', 'web-search_1', 'web-search_2', 'web-search_3', 'web-search_4', 'web-search_5'], 'connector': {'id': 'web-search'}}]
# 	search_queries: [{'text': 'What is OKE?', 'generation_id': '1604de91-200c-4931-9d71-e91d607942a7'}]
# }

# %% [markdown]
# ### Summarize

# %%
def summarize(text):
    return co.summarize(
        text=text,
        model="command-light-nightly"
    )

text=(
  "Ice cream is a sweetened frozen food typically eaten as a snack or dessert. "
  "It may be made from milk or cream and is flavoured with a sweetener, "
  "either sugar or an alternative, and a spice, such as cocoa or vanilla, "
  "or with fruit such as strawberries or peaches. "
  "It can also be made by whisking a flavored cream base and liquid nitrogen together. "
  "Food coloring is sometimes added, in addition to stabilizers. "
  "The mixture is cooled below the freezing point of water and stirred to incorporate air spaces "
  "and to prevent detectable ice crystals from forming. The result is a smooth, "
  "semi-solid foam that is solid at very low temperatures (below 2 °C or 35 °F). "
  "It becomes more malleable as its temperature increases.\n\n"
  "The meaning of the name \"ice cream\" varies from one country to another. "
  "In some countries, such as the United States, \"ice cream\" applies only to a specific variety, "
  "and most governments regulate the commercial use of the various terms according to the "
  "relative quantities of the main ingredients, notably the amount of cream. "
  "Products that do not meet the criteria to be called ice cream are sometimes labelled "
  "\"frozen dairy dessert\" instead. In other countries, such as Italy and Argentina, "
  "one word is used fo\r all variants. Analogues made from dairy alternatives, "
  "such as goat's or sheep's milk, or milk substitutes "
  "(e.g., soy, cashew, coconut, almond milk or tofu), are available for those who are "
  "lactose intolerant, allergic to dairy protein or vegan."
)

print(summarize(text))
# Out:
# SummarizeResponse(id='52c1354c-4e17-402b-9c52-e494bb377e8f', summary='Ice cream is a sweetened frozen food typically eaten as a snack or dessert. It may be made from milk or cream and is flavoured with a sweetener, either sugar or an alternative, and a spice, such as cocoa or vanilla, or with fruit such as strawberries or peaches. Food coloring is sometimes added, in addition to stabilizers. The mixture is cooled below the freezing point of water and stirred to incorporate air spaces and to prevent detectable ice crystals from forming. The result is a smooth, semi-solid foam that is solid at very low temperatures (below 2 °C or 35 °F). It becomes more malleable as its temperature increases. The meaning of the name "ice cream" varies from one country to another. In some countries, such as the United States, "ice cream" applies only to a specific variety, and most governments regulate the commercial use of the various terms according to the relative quantities of the main ingredients, notably the amount of cream. Products that do not meet the criteria to be called ice cream are sometimes labelled "frozen dairy dessert" instead. In other countries, such as Italy and Argentina, one word is used for all variants.', meta={'api_version': {'version': '1'}})

# %% [markdown]
# ### Embeddings

# %%
def get_embeddings(texts):
    return co.embed(
        texts=texts,
        model="embed-english-light-v2.0"
    )

texts = ["hello", "world"]
print(get_embeddings(texts))
# Out:
# cohere.Embeddings {
# 	embeddings: [[-0.16894531, -1.2080078, 0.5493164, -1.7099609, -1.5888672, 0.6010742, 0.6376953, 1.3916016, -0.49121094, -0.7397461, -1.796875, 1.5410156, 0.66064453, 0.9477539, -0.5395508, 0.24450684, 0.5292969, 0.23522949, 0.52734375, -1.3925781, 0.044006348, 0.86328125, -0.55908203, -0.4194336, 0.5522461, 3.578125, 7.2851562, -1.2529297, 1.3632812, 0.1340332, -1.1660156, 0.1239624, 2.6777344, -0.578125, -0.8623047, 1.3955078, 1.2480469, -0.41967773, 0.5527344, 1.5517578, 0.5732422, -0.35302734, 0.16027832, 0.6464844, -1.2382812, 0.06414795, -1.2402344, -2.2421875, -0.2536621, 1.6132812, -0.19970703, 0.35131836, -0.0287323, 0.44970703, 0.03591919, 0.8618164, 1.2158203, -0.53564453, 0.80810547, 1.4697266, 0.05718994, -0.10083008, -0.89746094, -0.5161133, -0.5961914, -1.5458984, -0.65722656, -1.5498047, -1.2382812, -1.2236328, -1.3623047, -0.7421875, 0.6977539, 0.63427734, -0.46362305, -0.96972656, 0.41870117, 0.7241211, 0.41308594, -1.4121094, 1.84375, 0.8183594, 1.3203125, 0.05923462, -0.51464844, -1.4746094, -0.14038086, -1.3847656, 0.8095703, 0.074401855, -1.6611328, 0.32421875, -2.2226562, -10.0625, -1.8105469, 1.0449219, -1.3466797, -1.1357422, -1.1445312, -0.13513184, 2.0410156, -1.1191406, 2.4160156, -1.4013672, 0.04788208, 1.2285156, 0.42578125, 0.8720703, 0.48486328, -0.18676758, 0.3347168, -1.0087891, 0.105529785, 1.1640625, 0.014640808, 0.9609375, 2.1894531, 1.2792969, -1.0605469, -1.0087891, 0.3359375, -0.52490234, -0.7524414, -1.7373047, 0.17211914, -1.4589844, 1.1933594, 1.8330078, 0.0124435425, 0.80126953, -1.1289062, 0.21972656, -1.1708984, 1.8193359, -0.16064453, 1.0449219, 1.8623047, 0.7739258, 1.2949219, -0.17443848, 0.59521484, -1.1103516, 1.6308594, -1.3896484, 1.0839844, -0.46142578, -1.0898438, 0.6557617, 0.37573242, 1.5986328, -1.5429688, 0.78808594, -1.2714844, -0.018066406, -0.20507812, -1.1582031, -0.79003906, 0.32885742, 0.5727539, 0.4008789, -1.2851562, 0.9399414, -1.9433594, 1.7841797, 0.6616211, -0.08795166, -2.828125, 2.4511719, 1.1132812, 0.06506348, -0.8989258, -1.0498047, 0.49414062, -0.24975586, -0.7480469, 1.4375, -0.21252441, 0.6816406, 1.0927734, -0.7709961, 0.22387695, 1.6728516, -0.5703125, -1.4550781, 0.26171875, 0.8041992, 1.0830078, -1.1064453, 0.3852539, -0.7338867, 1.5546875, -0.62109375, -1.2919922, 2.6152344, 1.9921875, -0.62060547, 1.3251953, 0.3828125, 1.7607422, 0.92822266, 0.22973633, 1.3740234, 0.040802002, -0.38452148, -0.16503906, 0.33496094, 0.9667969, 1.1425781, 0.052001953, 0.65771484, 0.41967773, 0.11871338, 0.015556335, 0.4519043, -0.53271484, -1.7763672, 1.3466797, -1.3105469, 0.20910645, 0.60839844, -0.94091797, 2.3574219, 0.14099121, 1.0732422, 0.8041992, 0.18701172, 0.32739258, 0.52978516, 1.0322266, -1.2001953, 0.09307861, 0.34179688, -0.65771484, -1.7919922, -0.18200684, 1.1738281, 0.018478394, -0.084350586, -0.48388672, -0.20275879, 0.17492676, -0.92822266, 0.66259766, -1.2265625, 0.8769531, 1.4970703, 0.27783203, 0.29541016, -0.2541504, 1.1953125, 1.671875, 0.8618164, 0.18383789, 1.9306641, -0.093688965, 0.77734375, 0.7558594, 0.061553955, 0.39794922, 0.67871094, 0.97265625, -0.40283203, 0.92089844, 1.1708984, 1.3017578, -0.19470215, -0.65283203, 1.7490234, -0.15124512, 0.12030029, 0.23461914, -0.03366089, -1.4121094, -0.33032227, -0.092163086, 0.2607422, -0.9140625, -0.07672119, -1.2685547, 1.5683594, 0.5756836, -0.30297852, -2.5585938, 1.2080078, 0.112854004, -0.7270508, -0.38793945, -0.6098633, 0.09136963, 1.5273438, 3.1347656, 1.4765625, 1.6865234, 2.9609375, -0.26513672, -0.79248047, -1.2929688, -0.08807373, 0.49560547, 0.7036133, -0.64746094, 1.3886719, -1.5009766, 1.0546875, 0.5888672, -1.0732422, -0.9301758, 1.6533203, -0.3310547, -0.8046875, 0.41430664, -0.54589844, 0.6855469, -0.56152344, 0.0057868958, -0.50634766, -2.5292969, -0.2734375, -1.8339844, 0.578125, 0.5004883, -0.47705078, -0.1315918, 0.98339844, -0.6376953, -0.18762207, -0.5209961, 0.5341797, 1.1035156, 0.082336426, -0.58447266, 0.58740234, -2.2734375, 0.17224121, -0.3720703, -0.39379883 ...
# 	compressed_embeddings: []
# 	meta: {'api_version': {'version': '1'}}
# }

# %% [markdown]
# ### Tokenize/Detokenize

# %%
def get_token(text):
    return co.tokenize(
        text = text,
        model = "command-light-nightly"
    )

def get_text_from_token(tokens):
    return co.detokenize(
        tokens=tokens,
        model="command-light-nightly"
    )

print("***** Tokenize *****")
token = get_token("tokenize me!")
print(token)

print("***** Detokenize *****")
print(get_text_from_token(token.tokens))
# Out:
# ***** Tokenize *****
# cohere.Tokens {
# 	tokens: [10002, 2261, 2012, 8]
# 	token_strings: ['token', 'ize', ' me', '!']
# 	meta: {'api_version': {'version': '1'}}
# }
# ***** Detokenize *****
# tokenize me!

# %% [markdown]
# ### Classify

# %%
from cohere.responses.classify import Example

examples=[
  Example("Dermatologists don't like her!", "Spam"),
  Example("'Hello, open to this?'", "Spam"),
  Example("I need help please wire me $1000 right now", "Spam"),
  Example("Nice to know you ;)", "Spam"),
  Example("Please help me?", "Spam"),
  Example("Your parcel will be delivered today", "Not spam"),
  Example("Review changes to our Terms and Conditions", "Not spam"),
  Example("Weekly sync notes", "Not spam"),
  Example("'Re: Follow up from today's meeting'", "Not spam"),
  Example("Pre-read for tomorrow", "Not spam"),
]

inputs=[
  "Confirm your email address",
  "hey i need u to send some $",
]

def classify(inputs, examples):
    return co.classify(
        inputs=inputs,
        examples=examples,
    )

print(classify(inputs, examples))
# Out:
# [Classification<prediction: "Not spam", confidence: 0.5661598, labels: {'Not spam': LabelPrediction(confidence=0.5661598), 'Spam': LabelPrediction(confidence=0.43384025)}>, Classification<prediction: "Spam", confidence: 0.9909811, labels: {'Not spam': LabelPrediction(confidence=0.009018883), 'Spam': LabelPrediction(confidence=0.9909811)}>]

# %% [markdown]
# ### Detect Language

# %%
def detect_language(texts):
    return co.detect_language(
        texts=texts,
    )

texts=['Hello world', "'Здравствуй, Мир'", 'こんにちは世界', '世界你好', '안녕하세요']

print(detect_language(texts))
# Out:
# cohere.DetectLanguageResponse {
# 	results: [Language<language_code: "en", language_name: "English">, Language<language_code: "ru", language_name: "Russian">, Language<language_code: "ja", language_name: "Japanese">, Language<language_code: "zh", language_name: "Chinese">, Language<language_code: "ko", language_name: "Korean">]
# 	meta: {'api_version': {'version': '1'}}
# }

# %% [markdown]
# ### Rerank

# %%
docs = [
    'Carson City is the capital city of the American state of Nevada.',
    'The Commonwealth of the Northern Mariana Islands is a group of islands in the Pacific Ocean. Its capital is Saipan.',
    'Washington, D.C. (also known as simply Washington or D.C., and officially as the District of Columbia) is the capital of the United States. It is a federal district.',
    'Capital punishment (the death penalty) has existed in the United States since beforethe United States was a country. As of 2017, capital punishment is legal in 30 of the 50 states.'
]

co_rerank = co.rerank(
    model='rerank-english-v2.0',
    query='What is the capital of the United States?',
    documents=docs
)

print(co_rerank)
# Out:
# [RerankResult<document['text']: Washington, D.C. (also known as simply Washington or D.C., and officially as the District of Columbia) is the capital of the United States. It is a federal district., index: 2, relevance_score: 0.98005307>, RerankResult<document['text']: Capital punishment (the death penalty) has existed in the United States since beforethe United States was a country. As of 2017, capital punishment is legal in 30 of the 50 states., index: 3, relevance_score: 0.27904198>, RerankResult<document['text']: Carson City is the capital city of the American state of Nevada., index: 0, relevance_score: 0.10194652>, RerankResult<document['text']: The Commonwealth of the Northern Mariana Islands is a group of islands in the Pacific Ocean. Its capital is Saipan., index: 1, relevance_score: 0.0721122>]
